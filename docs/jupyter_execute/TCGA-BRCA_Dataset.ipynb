# %% [markdown]
# # TCGA-BRCA Demo
#
# ## Dataset Source
#
# - **Omics Data**: [FireHose BRCA](http://firebrowse.org/?cohort=BRCA)
# - **Clinical and PAM50 Data**: [TCGAbiolinks](http://bioconductor.org/packages/release/bioc/html/TCGAbiolinks.html)
#
# ## Dataset Overview
#
# **Original Data**:
#
# - **Methylation**: 20,107 × 885
# - **mRNA**: 18,321 × 1,212
# - **miRNA**: 503 × 1,189
# - **PAM50**: 1,087 × 1
# - **Clinical**: 1,098 × 101
#
# - **Note: Omics matrices are features × samples; clinical matrices are samples × fields.**
#
# **PAM50 Subtype Counts**:
#
# - **LumA**: 419
# - **LumB**: 140
# - **Basal**: 130
# - **Her2**: 46
# - **Normal**: 34
#
# ## Patients in Every Dataset
#
# - Total patients present in methylation, mRNA, miRNA, PAM50, and clinical: **769**
#
# ## Final Shapes (Per-Patient)
#
# After aggregating multiple aliquots by mean, all modalities align on 769 patients:
#
# - **Methylation**: 769 × 20,107
# - **mRNA**: 769 × 20,531
# - **miRNA**: 769 × 503
# - **PAM50**: 769 × 1
# - **Clinical**: 769 × 119
#
# ## Data Summary Table
#
# | Stage                          | Clinical    | Methylation  | miRNA       | mRNA           | PAM50 (Subtype Counts)                                         | Notes                                   |
# | ------------------------------ | ----------- | ------------ | ----------- | -------------- | -------------------------------------------------------------- | --------------------------------------- |
# | **Original Raw Data**          | 1,098 × 101 | 20,107 × 885 | 503 × 1,189 | 18,321 × 1,212 | LumA: 509<br>LumB: 209<br>Basal: 192<br>Her2: 82<br>Normal: 40 | Raw FireHose & TCGAbiolinks files       |
# | **Patient-Level Intersection** | 769 × 101   | 769 × 20,107 | 769 × 1,046 | 769 × 20,531   | LumA: 419<br>LumB: 140<br>Basal: 130<br>Her2: 46<br>Normal: 34 | Patients with complete data in all sets |
#
# ## Reference Links
#
# - [FireHose BRCA](http://firebrowse.org/?cohort=BRCA)
# - [TCGAbiolinks](http://bioconductor.org/packages/release/bioc/html/TCGAbiolinks.html)
# - [Direct Download BRCA](http://firebrowse.org/?cohort=BRCA&download_dialog=true)

# %% [markdown]
# ## Lets take a look at the data from FireHose directly after download

# %%
import pandas as pd
from pathlib import Path
root = Path("/home/vicente/Github/BioNeuralNet/TCGA_BRCA_DATA")

mirna_raw = pd.read_csv(root/"BRCA.miRseq_RPKM_log2.txt", sep="\t",index_col=0,low_memory=False)                            
rna_raw = pd.read_csv(root / "BRCA.uncv2.mRNAseq_RSEM_normalized_log2.txt", sep="\t",index_col=0,low_memory=False)
meth_raw = pd.read_csv(root/"BRCA.meth.by_mean.data.txt", sep='\t',index_col=0,low_memory=False)
clinical_raw = pd.read_csv(root / "BRCA.clin.merged.picked.txt",sep="\t", index_col=0, low_memory=False)

print(f"mirna shape: {mirna_raw.shape}, rna shape: {rna_raw.shape}, meth shape: {meth_raw.shape}, clinical shape: {clinical_raw.shape}")
print(mirna_raw.head())
print(rna_raw.head())
print(meth_raw.head())
print(clinical_raw.head())
# Out:
# mirna shape: (503, 1189), rna shape: (18321, 1212), meth shape: (20107, 885), clinical shape: (18, 1097)
# ?|100134869         3.469873         3.850979         3.766489
# ?|10357             7.168565         6.395968         6.836141
# ?|10431             9.757450         9.581922         9.657753
# ?|155060            9.110487         8.027083         8.110023
#
#              TCGA-5L-AAT1-01  TCGA-5T-A9QA-01  TCGA-A1-A0SB-01  \
# gene
# ?|100133144              NaN         0.550310         3.939189
# ?|100134869         3.405298         3.169252         3.847346
# ?|10357             6.857961         6.749035         6.862786
# ?|10431            10.114256        10.472185         9.360367
# ?|155060            7.704865         6.254741         8.128052
#
#              TCGA-A1-A0SD-01  ...  TCGA-UL-AAZ6-01  TCGA-UU-A93S-01  \
# gene                          ...
# ?|100133144         3.250628  ...        -1.324816         2.108558
# ?|100134869         3.501324  ...         3.845189         3.443978
# ?|10357             5.913201  ...         7.083470         7.088829
# ?|10431             9.933569  ...        10.616682        11.495054
# ?|155060            6.387132  ...         8.052478         7.516236
#
#              TCGA-V7-A7HQ-01  TCGA-W8-A86G-01  TCGA-WT-AB41-01  \
# gene
# ?|100133144              NaN         2.475707              NaN
# ?|100134869         1.622556         3.845099         2.657434
# ?|10357             4.906766         7.003547         5.744909
# ?|10431            10.749770         9.446410        10.282241
# ?|155060            9.280761         9.631306         8.137225
#
#              TCGA-WT-AB44-01  TCGA-XX-A899-01  TCGA-XX-A89A-01  \
# gene
# ?|100133144              NaN         3.846574         4.480524
# ?|100134869         1.703987         4.422294         4.769476
# ?|10357             5.401368         7.106177         6.003213
# ?|10431            10.874534         9.350400         9.497295
# ?|155060            9.460539         8.738651         8.556414
#
#              TCGA-Z7-A8R5-01  TCGA-Z7-A8R6-01
# gene
# ?|100133144         1.178747         2.783771
# ?|100134869         2.866572         4.631075
# ?|10357             6.410173         7.388457
# ?|10431            10.155173         9.970921
# ?|155060            7.977670         7.894918
#
# [5 rows x 1212 columns]
#                       TCGA-3C-AAAU-01 TCGA-3C-AALI-01 TCGA-3C-AALJ-01  \
# Hybridization REF
# Composite Element REF      Beta_Value      Beta_Value      Beta_Value
# A1BG                   0.483716119676  0.637191226131  0.656092398242
# A1CF                   0.295827203492  0.458972998571  0.489725289638
# A2BP1                  0.187699869591  0.240515847704  0.279087851226
# A2LD1                   0.62958551322  0.666272288675  0.755630499986
#
#                       TCGA-3C-AALK-01 TCGA-4H-AAAK-01 TCGA-5L-AAT0-01  \
# Hybridization REF
# Composite Element REF      Beta_Value      Beta_Value      Beta_Value
# A1BG                   0.615194471357  0.612080370511  0.469600740678
# A1CF                   0.625765223243  0.507736509665  0.514770866326
# A2BP1                  0.488888510474  0.463845494635  0.504450855353
# A2LD1                   0.74575121287  0.698515739124  0.706812706661
#
#                       TCGA-5L-AAT1-01 TCGA-5T-A9QA-01 TCGA-A1-A0SB-01  \
# Hybridization REF
# Composite Element REF      Beta_Value      Beta_Value      Beta_Value
# A1BG                   0.582188239422   0.66617073097  0.659965611959
# A1CF                   0.549850958729  0.381038654448  0.826312156393
# A2BP1                  0.480885816745  0.622832399216  0.474678831563
# A2LD1                  0.759017355996  0.694010939885  0.847837522256
#
#                       TCGA-A1-A0SE-01  ... TCGA-UL-AAZ6-01 TCGA-UU-A93S-01  \
# Hybridization REF                      ...
# Composite Element REF      Beta_Value  ...      Beta_Value      Beta_Value
# A1BG                   0.641701155202  ...  0.631413241724   0.64952294395
# A1CF                   0.606699429409  ...  0.383469192855  0.183354853938
# A2BP1                  0.339829506578  ...  0.130529915536  0.319855310743
# A2LD1                  0.786662091353  ...  0.587475995313  0.667969642321
#
#                       TCGA-V7-A7HQ-01 TCGA-W8-A86G-01 TCGA-WT-AB41-01  \
# Hybridization REF
# Composite Element REF      Beta_Value      Beta_Value      Beta_Value
# A1BG                   0.596585169597  0.615558357651  0.580837880262
# A1CF                   0.403909161312  0.716980255014  0.613131295074
# A2BP1                  0.335517456053  0.512185396638  0.563519806811
# A2LD1                  0.689140211036  0.791381283524  0.680499323148
#
#                       TCGA-WT-AB44-01 TCGA-XX-A899-01 TCGA-XX-A89A-01  \
# Hybridization REF
# Composite Element REF      Beta_Value      Beta_Value      Beta_Value
# A1BG                   0.615814023324  0.589897794957  0.572606636128
# A1CF                   0.665043713213  0.705153725375  0.494848686021
# A2BP1                  0.507364324635  0.520542747167  0.412562068574
# A2LD1                  0.660476360054  0.745725420412   0.74390049875
#
#                       TCGA-Z7-A8R5-01 TCGA-Z7-A8R6-01
# Hybridization REF
# Composite Element REF      Beta_Value      Beta_Value
# A1BG                   0.617859586161  0.568150149265
# A1CF                   0.691835387189  0.224696596211
# A2BP1                  0.522169978143   0.33955834608
# A2LD1                  0.791229999577  0.637764188841
#
# [5 rows x 885 columns]
#                       tcga-5l-aat0 tcga-5l-aat1 tcga-a1-a0sp tcga-a2-a04v  \
# Hybridization REF
# Composite Element REF        value        value        value        value
# years_to_birth                  42           63           40           39
# vital_status                     0            0            0            1
# days_to_death                  NaN          NaN          NaN         1920
# days_to_last_followup         1477         1471          584          NaN
#
#                       tcga-a2-a04y tcga-a2-a0cq tcga-a2-a1g4 tcga-a2-a25a  \
# Hybridization REF
# Composite Element REF        value        value        value        value
# years_to_birth                  53           62           71           44
# vital_status                     0            0            0            0
# days_to_death                  NaN          NaN          NaN          NaN
# days_to_last_followup         1099         2695          595         3276
#
#                       tcga-a7-a0cd tcga-a7-a13g  ... tcga-s3-aa11  \
# Hybridization REF                                ...
# Composite Element REF        value        value  ...        value
# years_to_birth                  66           79  ...           67
# vital_status                     0            0  ...            0
# days_to_death                  NaN          NaN  ...          NaN
# days_to_last_followup         1165          718  ...          421
#
#                       tcga-s3-aa14 tcga-s3-aa15 tcga-ul-aaz6 tcga-uu-a93s  \
# Hybridization REF
# Composite Element REF        value        value        value        value
# years_to_birth                  47           51           73           63
# vital_status                     0            0            0            1
# days_to_death                  NaN          NaN          NaN          116
# days_to_last_followup          529          525          518          NaN
#
#                       tcga-v7-a7hq tcga-wt-ab44 tcga-xx-a899 tcga-xx-a89a  \
# Hybridization REF
# Composite Element REF        value        value        value        value
# years_to_birth                  75          NaN           46           68
# vital_status                     0            0            0            0
# days_to_death                  NaN          NaN          NaN          NaN
# days_to_last_followup         2033          883          467          488
#
#                       tcga-z7-a8r6
# Hybridization REF
# Composite Element REF        value
# years_to_birth                  46
# vital_status                     0
# days_to_death                  NaN
# days_to_last_followup         3256
#
# [5 rows x 1097 columns]

# %% [markdown]
# ## TCGA-BioLink
#
# This section demonstrates how to use the `TCGAbiolinks` R package to access and download clinical and molecular subtype data. It begins by ensuring `TCGAbiolinks` is installed, then loads the package. It retrieves PAM50 molecular subtype labels using `TCGAquery_subtype()` and writes them to a CSV file. Additionally, it downloads clinical data using `GDCquery_clinic()` and formats it with `GDCprepare_clinic()`, saving the result as another CSV file.

# %% [markdown]
# ```R
#   # Install TCGAbiolinks
#   if (!requireNamespace("TCGAbiolinks", quietly = TRUE)) {
#     if (!requireNamespace("BiocManager", quietly = TRUE))
#       install.packages("BiocManager")
#     BiocManager::install("TCGAbiolinks")
#   }
#
#   # Load the library
#   library(TCGAbiolinks)
#
#   # Download PAM50 subtype labels
#   pam50_df <- TCGAquery_subtype(tumor = "BRCA")[ , c("patient", "BRCA_Subtype_PAM50")]
#   write.csv(pam50_df, file = "BRCA_PAM50_labels.csv", row.names = FALSE, quote = FALSE)
#
#   # Download clinical data
#   clin_raw <- GDCquery_clinic(project = "TCGA-BRCA", type = "clinical")
#   clin_df <- GDCprepare_clinic(clin_raw, clinical.info = "patient")
#   write.csv(clin_df, file = "BRCA_clinical_data.csv", row.names = FALSE, quote = FALSE)
# ```

# %%
import pandas as pd

# from Firehose
mirna = pd.read_csv(root/"BRCA.miRseq_RPKM_log2.txt", sep="\t",index_col=0,low_memory=False)
meth = pd.read_csv(root/"BRCA.meth.by_mean.data.txt", sep='\t',index_col=0,low_memory=False)                             
rna = pd.read_csv(root / "BRCA.uncv2.mRNAseq_RSEM_normalized_log2.txt", sep="\t",index_col=0,low_memory=False)
clinical_firehose = pd.read_csv(root / "BRCA.clin.merged.picked.txt",sep="\t", index_col=0, low_memory=False).T

# from TCGABiolinks
pam50 = pd.read_csv(root /"BRCA_PAM50_labels.csv",index_col=0)
clinical_biolinks = pd.read_csv(root /"BRCA_clinical_data.csv",index_col=1)

print("Initial shapes")
print(f"meth: {meth.shape}")
print(f"rna: {rna.shape}")
print(f"mirna: {mirna.shape}")
print(f"pam50: {pam50.shape}")
print(f"clinical TCGABioLinks: {clinical_biolinks.shape}")
print(f"clinical FireHose: {clinical_firehose.shape}")

meth = meth.T
rna = rna.T
mirna = mirna.T

print("\nAfter tranpose")
print(f"meth: {meth.shape}")
print(f"rna: {rna.shape}")
print(f"mirna: {mirna.shape}")

def trim(idx):
    return idx.to_series().str.extract(r'(^TCGA-\w\w-\w\w\w\w)')[0]

meth.index = trim(meth.index)
rna.index = trim(rna.index)
mirna.index = trim(mirna.index)
pam50.index = pam50.index.str.upper()
clinical_biolinks.index = clinical_biolinks.index.str.upper()
clinical_firehose.index = clinical_firehose.index.str.upper()

idx1 = clinical_biolinks.index
idx2 = clinical_firehose.index

# intersection and unique counts
common = idx1.intersection(idx2)
only_in_1 = idx1.difference(idx2)
only_in_2 = idx2.difference(idx1)

print(f"Patients in both clinical datasets: {len(common)}")
common = clinical_biolinks.index.intersection(clinical_firehose.index)
clinical_biolinks = clinical_biolinks.loc[common]
clinical_firehose = clinical_firehose.loc[common]

clinical = pd.concat([clinical_biolinks, clinical_firehose], axis=1)

print(f"Combined Clinical shape {clinical.shape}")

common = sorted(set(meth.index) & set(rna.index) & set(mirna.index) & set(pam50.index) & set(clinical.index))
print(f"Patients in every dataset: {len(common)}")

meth = meth.loc[common]
rna = rna.loc[common]
mirna = mirna.loc[common]
pam50 = pam50.loc[common]
clinical = clinical.loc[common]

print("\nFinal shapes:")
print(f"meth: {meth.shape}")
print(f"rna: {rna.shape}")
print(f"mirna: {mirna.shape}")
print(f"pam50: {pam50.shape}")
print(f"clinical: {clinical.shape}\n")
# Out:
# Initial shapes
# meth: (20107, 885)
# rna: (18321, 1212)
# mirna: (503, 1189)
# pam50: (1087, 1)
# clinical TCGABioLinks: (1098, 101)
# clinical FireHose: (1097, 18)
#
# After tranpose
# meth: (885, 20107)
# rna: (1212, 18321)
# mirna: (1189, 503)
# Patients in both clinical datasets: 1097
# Combined Clinical shape (1097, 119)
# Patients in every dataset: 769
#
# Final shapes:
# meth: (863, 20107)
# rna: (865, 18321)
# mirna: (855, 503)
# pam50: (769, 1)
# clinical: (769, 119)

# %% [markdown]
# ## Handling Multiple Aliquots per Sample
#
# This section addresses cases where some patients have multiple aliquots per sample in the `meth`, `rna`, and `mirna` datasets. It first identifies and counts patients with duplicate entries. Then, it coerces all data to numeric types and aggregates the duplicates by computing the mean across aliquots for each patient, ensuring only one row per patient. After aggregation, the datasets are aligned by keeping only the patients that are common across all five datasets (`meth`, `rna`, `mirna`, `pam50`, and `clinical`). The result is s set of matched samples ready for integrated analysis.

# %%
for name, df in [("meth", meth), ("rna", rna), ("mirna", mirna)]:
    counts = df.index.value_counts()
    n_multiple = (counts > 1).sum()
    total_duplicates = counts[counts > 1].sum() - n_multiple
    
    print(f"{name}:")
    print(f"patients with >1 aliquot: {n_multiple}")
    print(f"total duplicate rows: {total_duplicates}\n")

meth = meth.apply(pd.to_numeric, errors="coerce")
rna = rna .apply(pd.to_numeric, errors="coerce")
mirna = mirna.apply(pd.to_numeric, errors="coerce")

meth = meth.groupby(level=0).mean()
rna = rna.groupby(level=0).mean()
mirna = mirna.groupby(level=0).mean()

# Now each has one row per patient
print("Post-aggregation shapes:")
print(f"meth: {meth.shape}")
print(f"rna: {rna.shape}")
print(f"mirna: {mirna.shape}")

common = sorted( set(meth.index) & set(rna.index) & set(mirna.index)& set(pam50.index) & set(clinical.index) )
print(f"Patients in every dataset: {len(common)}")

meth = meth.loc[common]
rna = rna.loc[common]
mirna = mirna.loc[common]
pam50 = pam50.loc[common]
clinical = clinical.loc[common]

print("\nFinal shapes")
print(f"meth: {meth.shape}")
print(f"rna: {rna.shape}")
print(f"mirna: {mirna.shape}")
print(f"pam50: {pam50.shape}")
print(f"clinical:{clinical.shape}")
# Out:
# meth:
# patients with >1 aliquot: 91
# total duplicate rows: 94
#
# rna:
# patients with >1 aliquot: 93
# total duplicate rows: 96
#
# mirna:
# patients with >1 aliquot: 84
# total duplicate rows: 86
#
# Post-aggregation shapes:
# meth: (769, 20107)
# rna: (769, 18321)
# mirna: (769, 503)
# Patients in every dataset: 769
#
# Final shapes
# meth: (769, 20107)
# rna: (769, 18321)
# mirna: (769, 503)
# pam50: (769, 1)
# clinical:(769, 119)

# %% [markdown]
# ## Review the first few rows of each file

# %%
print(meth.head())
print(rna.head())
print(mirna.head())
print(clinical.head())
print(pam50.value_counts())
# Out:
# Hybridization REF  Composite Element REF      A1BG      A1CF     A2BP1  \
# 0
# TCGA-3C-AAAU                         NaN  0.483716  0.295827  0.187700
# TCGA-3C-AALI                         NaN  0.637191  0.458973  0.240516
# TCGA-3C-AALJ                         NaN  0.656092  0.489725  0.279088
# TCGA-3C-AALK                         NaN  0.615194  0.625765  0.488889
# TCGA-4H-AAAK                         NaN  0.612080  0.507737  0.463845
#
# Hybridization REF     A2LD1       A2M     A2ML1    A4GALT     A4GNT      AAA1  \
# 0
# TCGA-3C-AAAU       0.629586  0.559654  0.835412  0.484800  0.690217  0.807805
# TCGA-3C-AALI       0.666272  0.607505  0.842391  0.550047  0.749890  0.395290
# TCGA-3C-AALJ       0.755630  0.662360  0.829020  0.476107  0.653756  0.795102
# TCGA-3C-AALK       0.745751  0.727982  0.835365  0.556016  0.652005  0.816423
# TCGA-4H-AAAK       0.698516  0.692364  0.802388  0.504870  0.531183  0.851114
#
# Hybridization REF  ...    ZWILCH     ZWINT      ZXDC    ZYG11A    ZYG11B  \
# 0                  ...
# TCGA-3C-AAAU       ...  0.112978  0.053939  0.287665  0.328087  0.502935
# TCGA-3C-AALI       ...  0.111834  0.046160  0.265322  0.405851  0.434024
# TCGA-3C-AALJ       ...  0.113218  0.042657  0.272103  0.391326  0.449525
# TCGA-3C-AALK       ...  0.145133  0.047022  0.301284  0.410348  0.446571
# TCGA-4H-AAAK       ...  0.118928  0.045057  0.300647  0.379998  0.487929
#
# Hybridization REF       ZYX     ZZEF1      ZZZ3  psiTPTE22      tAKR
# 0
# TCGA-3C-AAAU       0.220683  0.482044  0.107396   0.247304  0.506404
# TCGA-3C-AALI       0.236362  0.458847  0.119652   0.163022  0.623865
# TCGA-3C-AALJ       0.210976  0.482641  0.102385   0.252328  0.504451
# TCGA-3C-AALK       0.220185  0.485944  0.112941   0.471956  0.682468
# TCGA-4H-AAAK       0.233324  0.490736  0.115646   0.314877  0.744877
#
# [5 rows x 20107 columns]
# gene          ?|100133144  ?|100134869   ?|10357    ?|10431   ?|155060  \
# 0
# TCGA-3C-AAAU     4.032489     3.692829  5.704604   8.672694  10.213110
# TCGA-3C-AALI     3.211931     4.119273  6.124231   9.139279   9.011343
# TCGA-3C-AALJ     3.538886     3.206237  7.269570  10.410275   9.209506
# TCGA-3C-AALK     3.595671     3.469873  7.168565   9.757450   9.110487
# TCGA-4H-AAAK     2.775430     3.850979  6.395968   9.581922   8.027083
#
# gene           ?|26823  ?|340602  ?|388795  ?|390284  ?|391343  ...  \
# 0                                                               ...
# 0
# TCGA-3C-AAAU     2.467414     1.044202    2.044202    6.906699    5.754696
# TCGA-3C-AALI     3.032109    -0.668331    0.331670    5.912870    6.427066
# TCGA-3C-AALJ     1.855261    -0.381778    0.717757    6.603657    6.878301
# TCGA-3C-AALK     1.798435     1.798435    0.798435    6.181354    5.377922
# TCGA-4H-AAAK     1.076036     0.182950   -0.302475    4.318110    5.103516
#
# gene          hsa-mir-99a  hsa-mir-99b
# 0
# TCGA-3C-AAAU     7.024602    15.506461
# TCGA-3C-AALI     7.885299    13.626182
# TCGA-3C-AALJ     7.580704    15.013822
# TCGA-3C-AALK    10.031619    14.554783
# TCGA-4H-AAAK    10.078201    14.650338
#
# [5 rows x 503 columns]
#                 project synchronous_malignancy ajcc_pathologic_stage  \
# TCGA-3C-AAAU  TCGA-BRCA                     No               Stage X
# TCGA-3C-AALI  TCGA-BRCA                     No             Stage IIB
# TCGA-3C-AALJ  TCGA-BRCA                     No             Stage IIB
# TCGA-3C-AALK  TCGA-BRCA                     No              Stage IA
# TCGA-4H-AAAK  TCGA-BRCA                     No            Stage IIIA
#
#               days_to_diagnosis laterality  created_datetime  \
# TCGA-3C-AAAU                0.0       Left               NaN
# TCGA-3C-AALI                0.0      Right               NaN
# TCGA-3C-AALJ                0.0      Right               NaN
# TCGA-3C-AALK                0.0      Right               NaN
# TCGA-4H-AAAK                0.0       Left               NaN
#
#              last_known_disease_status tissue_or_organ_of_origin  \
# TCGA-3C-AAAU                       NaN               Breast, NOS
# TCGA-3C-AALI                       NaN               Breast, NOS
# TCGA-3C-AALJ                       NaN               Breast, NOS
# TCGA-3C-AALK                       NaN               Breast, NOS
# TCGA-4H-AAAK                       NaN               Breast, NOS
#
#               days_to_last_follow_up  age_at_diagnosis  ... pathology_N_stage  \
# TCGA-3C-AAAU                     NaN           20211.0  ...                nx
# TCGA-3C-AALI                     NaN           18538.0  ...               n1a
# TCGA-3C-AALJ                     NaN           22848.0  ...               n1a
# TCGA-3C-AALK                     NaN           19074.0  ...           n0 (i+)
# TCGA-4H-AAAK                     NaN           18371.0  ...               n2a
#
#              pathology_M_stage  gender date_of_initial_pathologic_diagnosis  \
# TCGA-3C-AAAU                mx  female                                 2004
# TCGA-3C-AALI                m0  female                                 2003
# TCGA-3C-AALJ                m0  female                                 2011
# TCGA-3C-AALK                m0  female                                 2011
# TCGA-4H-AAAK                m0  female                                 2013
#
#               days_to_last_known_alive radiation_therapy  \
# TCGA-3C-AAAU                       NaN                no
# TCGA-3C-AALI                       NaN               yes
# TCGA-3C-AALJ                       NaN                no
# TCGA-3C-AALK                       NaN                no
# TCGA-4H-AAAK                       NaN                no
#
#                            histological_type number_of_lymph_nodes  \
# TCGA-3C-AAAU  infiltrating lobular carcinoma                     4
# TCGA-3C-AALI   infiltrating ductal carcinoma                     1
# TCGA-3C-AALJ   infiltrating ductal carcinoma                     1
# TCGA-3C-AALK   infiltrating ductal carcinoma                     0
# TCGA-4H-AAAK  infiltrating lobular carcinoma                     4
#
#                                    race               ethnicity
# TCGA-3C-AAAU                      white  not hispanic or latino
# TCGA-3C-AALI  black or african american  not hispanic or latino
# TCGA-3C-AALJ  black or african american  not hispanic or latino
# TCGA-3C-AALK  black or african american  not hispanic or latino
# TCGA-4H-AAAK                      white  not hispanic or latino
#
# [5 rows x 119 columns]
# BRCA_Subtype_PAM50
# LumA                  419
# LumB                  140
# Basal                 130
# Her2                   46
# Normal                 34
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing
#
# After reviewing the data above, we applied the following steps to the data before further analysis.
#
# 1. Methylation (B -> M-value)
#    - Clip B-values to \[E, 1-E] and apply logit transform: M = log_2(B / (1-B)).
#    - Drop the original `Composite Element REF` column.
#
# 2. mRNA & miRNA:
#    - Already in log_2 scale (RSEM normalized and RPKM).
#
# 3. Quality Control:
#    - Count samples with all-zero rows in each modality.
#    - Compute NaN counts post-transformation, then replace all NaNs with 0.
#
# 4. Column Name Cleaning:
#    - Replace all `-` and `|` characters with `_`.
#    - Replace `?` with `unknown`.
#
# 5. Label Encoding:
#    - Map `PAM50` subtypes to integers:
#       - Normal = 0
#       - Basal = 1
#       - Her2 = 2
#       - LumA = 3
#       - LumB = 4
#
# 6. Alignment & Aggregation:
#    - Trim barcodes to patient level.
#    - Aggregate duplicate aliquots by mean per patient.
#    - Drop the `project` column from clinical.
#    - Subset all tables to the common patient set (no missing or all-zero samples).
#    - Set up a commong index across all files.
#
# 7. Final Output Shapes:
#    - Methylation M-value: 769 × 20,107
#    - mRNA (log_2): 769 × 20,531
#    - miRNA (log_2): 769 × 503
#    - PAM50 labels: 769 × 1
#    - Clinical covariates: 769 × 101

# %%
import numpy as np
import pandas as pd

def beta_to_m(df, eps=1e-6):
    B = np.clip(df.values, eps, 1.0 - eps)
    M = np.log2(B / (1 - B))
    return pd.DataFrame(M, index=df.index, columns=df.columns)

# find rows that are all 0s
zeros_meth = (meth  == 0).all(axis=1).sum()
zeros_rna = (rna   == 0).all(axis=1).sum()
zeros_mirna = (mirna == 0).all(axis=1).sum()
print(f"All zeros: meth: {zeros_meth}, rna: {zeros_rna}, mirna: {zeros_mirna}")

# find rows with all nans
nan_meth = meth.isna().all(axis=1).sum()
nan_rna = rna.isna().all(axis=1).sum()
nan_mirna = mirna.isna().all(axis=1).sum()
nan_clinical = clinical.isna().all(axis=1).sum()
nan_pam50 = pam50.isna().all(axis=1).sum()
print(f"nan_meth: {nan_meth}, nan_rna: {nan_rna}, nan_mirna: {nan_mirna}, nan_clinical: {nan_clinical}, nan_pam50: {nan_pam50}")

# map PAM50 subtypes to integers
mapping = {"Normal":0, "Basal":1, "Her2":2, "LumA":3, "LumB":4}
pam50 = pam50["BRCA_Subtype_PAM50"].map(mapping).to_frame(name="pam50")

# drop and transform methylation
meth_clean = meth.drop(columns=["Composite Element REF"], errors="ignore")
meth_m = beta_to_m(meth_clean)
clinical = clinical.drop(columns=["project"], errors="ignore")

# clean column names and fill nans
for df in [meth_m, rna, mirna]:
    df.columns = df.columns.str.replace(r"\?", "unknown_", regex=True)
    df.columns = df.columns.str.replace(r"\|", "_", regex=True)
    df.columns = df.columns.str.replace("-", "_", regex=False)
    df.columns = df.columns.str.replace(r"_+", "_", regex=True)
    df.columns = df.columns.str.strip("_")
    df.fillna(0, inplace=True)

# check for nans after filling
print("NaN counts after filling:")
print(meth_m.isna().sum().sum(),rna.isna().sum().sum(),mirna.isna().sum().sum(),clinical.isna().sum().sum(),pam50.isna().sum().sum())

# align index to PAM50
X_meth = meth_m.loc[pam50.index]
X_rna = rna.loc[pam50.index]
X_mirna = mirna.loc[pam50.index]
clinical= clinical.loc[pam50.index]

print(f"new shapes: meth: {X_meth.shape}, rna: {X_rna.shape}, mirna: {X_mirna.shape}, pam50: {pam50.shape}, clinical: {clinical.shape}")
print(X_meth.head())
print(X_rna.head())
print(X_mirna.head())
print(clinical.head())
print(pam50.value_counts())
# Out:
# All zeros: meth: 0, rna: 0, mirna: 0
# nan_meth: 0, nan_rna: 0, nan_mirna: 0, nan_clinical: 0, nan_pam50: 0
# NaN counts after filling:
# 0 0 0 46476 0
# new shapes: meth: (769, 20106), rna: (769, 18321), mirna: (769, 503), pam50: (769, 1), clinical: (769, 118)
# Hybridization REF      A1BG      A1CF     A2BP1     A2LD1       A2M     A2ML1  \
# patient
# TCGA-3C-AAAU      -0.094004 -1.251175 -2.113585  0.765262  0.345896  2.343631
# TCGA-3C-AALI       0.812517 -0.237291 -1.658888  0.997440  0.630221  2.418135
# TCGA-3C-AALJ       0.931878 -0.059301 -1.369104  1.628617  0.972130  2.277584
# TCGA-3C-AALK       0.676913  0.741678 -0.064133  1.552454  1.420200  2.343133
# TCGA-4H-AAAK       0.657963  0.044649 -0.209004  1.212210  1.170304  2.021628
#
# Hybridization REF    A4GALT     A4GNT      AAA1      AAAS  ...    ZWILCH  \
# patient                                                    ...
# TCGA-3C-AAAU      -0.087741  1.155791  2.071436 -2.650851  ... -2.972923
# TCGA-3C-AALI       0.289780  1.584114 -0.613329 -4.072465  ... -2.989465
# TCGA-3C-AALJ      -0.137988  0.916964  1.956230 -3.781647  ... -2.969472
# TCGA-3C-AALK       0.324621  0.905816  2.152928 -3.894574  ... -2.558319
# TCGA-4H-AAAK       0.028103  0.180184  2.515149 -3.885526  ... -2.889175
#
# Hybridization REF     ZWINT      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# patient
# TCGA-3C-AAAU      -4.132523 -1.308165 -1.034199  0.016935 -1.820233 -0.103662
# TCGA-3C-AALI      -4.369032 -1.469365 -0.549876 -0.382967 -1.691887 -0.238022
# TCGA-3C-AALJ      -4.488190 -1.419578 -0.637297 -0.292273 -1.902991 -0.100215
# TCGA-3C-AALK      -4.341028 -1.213585 -0.523013 -0.309506 -1.824419 -0.081137
# TCGA-4H-AAAK      -4.405580 -1.217950 -0.706284 -0.069670 -1.716283 -0.053464
#
# Hybridization REF      ZZZ3  psiTPTE22      tAKR
# patient
# TCGA-3C-AAAU      -3.055084  -1.605783  0.036955
# TCGA-3C-AALI      -2.879231  -2.360128  0.729981
# patient
# TCGA-3C-AAAU    8.414890    8.665921   10.521777      3.879392     11.824817
# TCGA-3C-AALI    9.646536    9.003653    9.131760      4.386952     12.678841
# TCGA-3C-AALJ    9.312455    9.276943   11.395711      5.314692     13.530255
# TCGA-3C-AALK   11.511431    8.384763   10.368981      4.159182     12.652559
# TCGA-4H-AAAK   11.693927    8.453747   10.741371      4.494537     13.009499
#
# gene          hsa_let_7g  ...  hsa_mir_937  hsa_mir_939  hsa_mir_940  \
# patient                   ...
# TCGA-3C-AAAU    8.597744  ...     0.906699    -0.093302     2.672234
# TCGA-3C-AALI    8.455144  ...     1.579597    -0.083367     0.139024
# TCGA-3C-AALJ    9.230563  ...     3.270298    -2.189134     0.395828
# TCGA-3C-AALK    8.471503  ...     0.923965    -0.660997    -0.076034
# TCGA-4H-AAAK    8.381220  ...     0.182950    -0.624403    -1.624403
#
# gene          hsa_mir_942  hsa_mir_944  hsa_mir_95  hsa_mir_96  hsa_mir_98  \
# patient
# TCGA-3C-AAAU     2.467414     1.044202    2.044202    6.906699    5.754696
# TCGA-3C-AALI     3.032109    -0.668331    0.331670    5.912870    6.427066
# TCGA-3C-AALJ     1.855261    -0.381778    0.717757    6.603657    6.878301
# TCGA-3C-AALK     1.798435     1.798435    0.798435    6.181354    5.377922
# TCGA-4H-AAAK     1.076036     0.182950   -0.302475    4.318110    5.103516
#
# gene          hsa_mir_99a  hsa_mir_99b
# patient
# TCGA-3C-AAAU     7.024602    15.506461
# TCGA-3C-AALI     7.885299    13.626182
# TCGA-3C-AALJ     7.580704    15.013822
# TCGA-3C-AALK    10.031619    14.554783
# TCGA-4H-AAAK    10.078201    14.650338
#
# [5 rows x 503 columns]
#              synchronous_malignancy ajcc_pathologic_stage  days_to_diagnosis  \
# patient
# TCGA-3C-AAAU                     No               Stage X                0.0
# TCGA-3C-AALI                     No             Stage IIB                0.0
# TCGA-3C-AALJ                     No             Stage IIB                0.0
# TCGA-3C-AALK                     No              Stage IA                0.0
# TCGA-4H-AAAK                     No            Stage IIIA                0.0
#
#              laterality  created_datetime last_known_disease_status  \
# patient
# TCGA-3C-AAAU       Left               NaN                       NaN
# TCGA-3C-AALI      Right               NaN                       NaN
# TCGA-3C-AALJ      Right               NaN                       NaN
# TCGA-3C-AALK      Right               NaN                       NaN
# TCGA-4H-AAAK       Left               NaN                       NaN
#
#              tissue_or_organ_of_origin  days_to_last_follow_up  \
# patient
# TCGA-3C-AAAU               Breast, NOS                     NaN
# TCGA-3C-AALI               Breast, NOS                     NaN
# TCGA-3C-AALJ               Breast, NOS                     NaN
# TCGA-3C-AALK               Breast, NOS                     NaN
# TCGA-4H-AAAK               Breast, NOS                     NaN
#
#               age_at_diagnosis                 primary_diagnosis  ...  \
# patient                                                           ...
# TCGA-3C-AAAU           20211.0            Lobular carcinoma, NOS  ...
# TCGA-3C-AALI           18538.0  Infiltrating duct carcinoma, NOS  ...
# TCGA-3C-AALJ           22848.0  Infiltrating duct carcinoma, NOS  ...
# TCGA-3C-AALK           19074.0  Infiltrating duct carcinoma, NOS  ...
# TCGA-4H-AAAK           18371.0            Lobular carcinoma, NOS  ...
#
#              pathology_N_stage pathology_M_stage  gender  \
# patient
# TCGA-3C-AAAU                nx                mx  female
# TCGA-3C-AALI               n1a                m0  female
# TCGA-3C-AALJ               n1a                m0  female
# TCGA-3C-AALK           n0 (i+)                m0  female
# TCGA-4H-AAAK               n2a                m0  female
#
#               date_of_initial_pathologic_diagnosis days_to_last_known_alive  \
# patient
# TCGA-3C-AAAU                                  2004                      NaN
# TCGA-3C-AALI                                  2003                      NaN
# TCGA-3C-AALJ                                  2011                      NaN
# TCGA-3C-AALK                                  2011                      NaN
# TCGA-4H-AAAK                                  2013                      NaN
#
#              radiation_therapy               histological_type  \
# patient
# TCGA-3C-AAAU                no  infiltrating lobular carcinoma
# TCGA-3C-AALI               yes   infiltrating ductal carcinoma
# TCGA-3C-AALJ                no   infiltrating ductal carcinoma
# TCGA-3C-AALK                no   infiltrating ductal carcinoma
# TCGA-4H-AAAK                no  infiltrating lobular carcinoma
#
#               number_of_lymph_nodes                       race  \
# patient
# TCGA-3C-AAAU                      4                      white
# TCGA-3C-AALI                      1  black or african american
# TCGA-3C-AALJ                      1  black or african american
# TCGA-3C-AALK                      0  black or african american
# TCGA-4H-AAAK                      4                      white
#
#                            ethnicity
# patient
# TCGA-3C-AAAU  not hispanic or latino
# TCGA-3C-AALI  not hispanic or latino
# TCGA-3C-AALJ  not hispanic or latino
# TCGA-3C-AALK  not hispanic or latino
# TCGA-4H-AAAK  not hispanic or latino
#
# [5 rows x 118 columns]
# pam50
# 3        419
# 4        140
# 1        130
# 2         46
# 0         34
# Name: count, dtype: int64

# %%
# Setting up a commong index and saving to csv
X_meth.index.name = "patient"
X_rna.index.name = "patient"
X_mirna.index.name = "patient"
pam50.index.name = "patient"
clinical.index.name = "patient"

X_meth.to_csv(root / "meth.csv", index=True)
X_rna.to_csv(root / "rna.csv", index=True)
X_mirna.to_csv(root / "mirna.csv", index=True)
pam50.to_csv(root / "pam50.csv", index=True)
clinical.to_csv(root / "clinical.csv", index=True)

# %%
# To confirm our data saved and loads properly:
meth = pd.read_csv(root / "meth.csv", index_col=0)
rna = pd.read_csv(root / "rna.csv", index_col=0)
mirna = pd.read_csv(root / "mirna.csv", index_col=0)
pam50 = pd.read_csv(root / "pam50.csv", index_col=0)
clinical = pd.read_csv(root / "clinical.csv", index_col=0)
    
print(meth.head())
print(rna.head())
print(mirna.head())
print(clinical.head())
print(pam50.head())
# Out:
#                   A1BG      A1CF     A2BP1     A2LD1       A2M     A2ML1  \
# patient
# TCGA-3C-AAAU -0.094004 -1.251175 -2.113585  0.765262  0.345896  2.343631
# TCGA-3C-AALI  0.812517 -0.237291 -1.658888  0.997440  0.630221  2.418135
# TCGA-3C-AALJ  0.931878 -0.059301 -1.369104  1.628617  0.972130  2.277584
# TCGA-3C-AALK  0.676913  0.741678 -0.064133  1.552454  1.420200  2.343133
# TCGA-4H-AAAK  0.657963  0.044649 -0.209004  1.212210  1.170304  2.021628
# patient
# TCGA-3C-AAAU                     No               Stage X                0.0
# TCGA-3C-AALI                     No             Stage IIB                0.0
# TCGA-3C-AALJ                     No             Stage IIB                0.0
# TCGA-3C-AALK                     No              Stage IA                0.0
# TCGA-4H-AAAK                     No            Stage IIIA                0.0
#
#              laterality  created_datetime  last_known_disease_status  \
# patient
# TCGA-3C-AAAU       Left               NaN                        NaN
# TCGA-3C-AALI      Right               NaN                        NaN
# TCGA-3C-AALJ      Right               NaN                        NaN
# TCGA-3C-AALK      Right               NaN                        NaN
# TCGA-4H-AAAK       Left               NaN                        NaN
#
#              tissue_or_organ_of_origin  days_to_last_follow_up  \
# patient
# TCGA-3C-AAAU               Breast, NOS                     NaN
# TCGA-3C-AALI               Breast, NOS                     NaN
# TCGA-3C-AALJ               Breast, NOS                     NaN
# TCGA-3C-AALK               Breast, NOS                     NaN
# TCGA-4H-AAAK               Breast, NOS                     NaN
#
#               age_at_diagnosis                 primary_diagnosis  ...  \
# patient                                                           ...
# TCGA-3C-AAAU           20211.0            Lobular carcinoma, NOS  ...
# TCGA-3C-AALI           18538.0  Infiltrating duct carcinoma, NOS  ...
# TCGA-3C-AALJ           22848.0  Infiltrating duct carcinoma, NOS  ...
# TCGA-3C-AALK           19074.0  Infiltrating duct carcinoma, NOS  ...
# TCGA-4H-AAAK           18371.0            Lobular carcinoma, NOS  ...
#
#              pathology_N_stage pathology_M_stage gender.1  \
# patient
# TCGA-3C-AAAU                nx                mx   female
# TCGA-3C-AALI               n1a                m0   female
# TCGA-3C-AALJ               n1a                m0   female
# TCGA-3C-AALK           n0 (i+)                m0   female
# TCGA-4H-AAAK               n2a                m0   female
#
#               date_of_initial_pathologic_diagnosis days_to_last_known_alive  \
# patient
# TCGA-3C-AAAU                                2004.0                      NaN
# TCGA-3C-AALI                                2003.0                      NaN
# TCGA-3C-AALJ                                2011.0                      NaN
# TCGA-3C-AALK                                2011.0                      NaN
# TCGA-4H-AAAK                                2013.0                      NaN
#
#              radiation_therapy               histological_type  \
# patient
# TCGA-3C-AAAU                no  infiltrating lobular carcinoma
# TCGA-3C-AALI               yes   infiltrating ductal carcinoma
# TCGA-3C-AALJ                no   infiltrating ductal carcinoma
# TCGA-3C-AALK                no   infiltrating ductal carcinoma
# TCGA-4H-AAAK                no  infiltrating lobular carcinoma
#
#               number_of_lymph_nodes                     race.1  \
# patient
# TCGA-3C-AAAU                    4.0                      white
# TCGA-3C-AALI                    1.0  black or african american
# TCGA-3C-AALJ                    1.0  black or african american
# TCGA-3C-AALK                    0.0  black or african american
# TCGA-4H-AAAK                    4.0                      white
#
#                          ethnicity.1
# patient
# TCGA-3C-AAAU  not hispanic or latino
# TCGA-3C-AALI  not hispanic or latino
# TCGA-3C-AALJ  not hispanic or latino
# TCGA-3C-AALK  not hispanic or latino
# TCGA-4H-AAAK  not hispanic or latino
#
# [5 rows x 118 columns]
#               pam50
# patient
# TCGA-3C-AAAU      3
# TCGA-3C-AALI      2
# TCGA-3C-AALJ      4
# TCGA-3C-AALK      3
# TCGA-4H-AAAK      3

# %% [markdown]
# ## Feature Selection
#
# To support downstream analysis, we provide three built-in feature selection methods: +
# - variance thresholding
# - ANOVA F-test
# - Random Forest importance.
#
# These are designed to help users quickly identify the most informative features from high-dimensional omics datasets. Each method captures different statistical properties, ranging from general variability to class-based separability and model-derived relevance. In this section, we put all three to the test and examine how much they agree with each other.

# %%
from bioneuralnet.utils.preprocess import select_top_k_variance
from bioneuralnet.utils.preprocess import top_anova_f_features
from bioneuralnet.utils.preprocess import select_top_randomforest

# feature selection
meth_highvar = select_top_k_variance(meth, k=6000)
rna_highvar = select_top_k_variance(rna, k=6000)

meth_af = top_anova_f_features(meth, pam50, max_features=6000)
rna_af = top_anova_f_features(rna, pam50, max_features=6000)

meth_rf = select_top_randomforest(meth, pam50, top_k=6000)
rna_rf = select_top_randomforest(rna, pam50, top_k=6000)

meth_var = list(meth_highvar.columns)
meth_anova = list(meth_af.columns)
meth_rf = list(meth_rf.columns)

rna_var = list(rna_highvar.columns)
rna_anova = list(rna_af.columns)
rna_rf = list(rna_rf.columns)

inter1 = []
for x in meth_anova:
    if x in meth_var:
        inter1.append(x)

inter2 = []
for x in meth_rf:
    if x in meth_var:
        inter2.append(x)

inter3 = []
for x in meth_anova:
    if x in meth_rf:
        inter3.append(x)

meth_all_three = []
for x in meth_anova:
    if x in meth_rf and x in meth_var:
        meth_all_three.append(x)

inter4 = []
for x in rna_anova:
    if x in rna_var:
        inter4.append(x)

inter5 = []
for x in rna_rf:
    if x in rna_var:
        inter5.append(x)

inter6 = []
for x in rna_anova:
    if x in rna_rf:
        inter6.append(x)

rna_all_three = []
for x in rna_anova:
    if x in rna_rf and x in rna_var:
        rna_all_three.append(x)

# %%
print("Methylation feature selection:\n")
print(f"Anova-F & variance selection share: {len(inter1)} features")
print(f"Random Forest & variance selection share: {len(inter2)} features")
print(f"Anova-F & Random Forest share: {len(inter3)} features")
print(f"All three methods agree on: {len(meth_all_three)} features")
# Out:
# Methylation feature selection:
#
# Anova-F & variance selection share: 2091 features
# Random Forest & variance selection share: 1871 features
# Anova-F & Random Forest share: 2201 features
# All three methods agree on: 815 features

# %%
print("\nRNA feature selection:\n")
print(f"Anova-F & variance selection share: {len(inter4)} features")
print(f"Random Forest & variance selection share: {len(inter5)} features")
print(f"Anova-F & Random Forest share: {len(inter6)} features")
print(f"All three methods agree on: {len(rna_all_three)} features")
# Out:
# RNA feature selection:
#
# Anova-F & variance selection share: 2340 features
# Random Forest & variance selection share: 2218 features
# Anova-F & Random Forest share: 2546 features
# All three methods agree on: 1134 features

# %%
out_dir = Path("/home/vicente/Github/BioNeuralNet/TCGA_BRCA_DATA/ANOVA")

rna_af.to_csv(out_dir / "rna_anova.csv")
meth_af.to_csv(out_dir / "meth_anova.csv")

# %% [markdown]
# ## Easy Access via DatasetLoader
#
# To facilitate working with this data, we have made it available through our `DatasetLoader` component. Due to GitHub and PyPI file size limitations, we selected the top 6,000 features from each omics modality using ANOVA F-test. If you have additional pre-processed or raw datasets you would like to include, feel free to reach out, we are happy to support expanding the platform and adding new datasets.

# %%
from bioneuralnet.datasets import DatasetLoader

tgca_brca = DatasetLoader("brca")

print(f"TGCA BRCA dataset shape: {tgca_brca.shape}")
brca_meth = tgca_brca.data["meth"]
brca_rna = tgca_brca.data["rna"]
brca_mirna = tgca_brca.data["mirna"]
brca_clinical = tgca_brca.data["clinical"]
brca_pam50 = tgca_brca.data["pam50"]
# Out:
# TGCA BRCA dataset shape: {'mirna': (769, 503), 'pam50': (769, 1), 'clinical': (769, 118), 'rna': (769, 6000), 'meth': (769, 6000)}

# %%
from bioneuralnet.utils.preprocess import preprocess_clinical

#shapes
print(f"RNA shape: {brca_rna.shape}")
print(f"METH shape: {brca_meth.shape}")
print(f"miRNA shape: {brca_mirna.shape}")
print(f"Clinical shape: {brca_clinical.shape}")
print(f"Phenotype shape: {brca_pam50.shape}")
print(f"Phenotype counts:\n{brca_pam50.value_counts()}")

#check nans in pam50
print(f"Nan values in pam50 {brca_pam50.isna().sum().sum()}")
brca_pam50 = brca_pam50.dropna()

X_rna = brca_rna.loc[brca_pam50.index]
X_meth = brca_meth.loc[brca_pam50.index]
X_mirna = brca_mirna.loc[brca_pam50.index]
clinical = brca_clinical.loc[brca_pam50.index]

# for more details on the preprocessing function, see bioneuralnet.utils.preprocess
clinical = preprocess_clinical(clinical, brca_pam50, top_k=15, scale=True, ignore_columns=["days_to_birth", "age_at_diagnosis", "days_to_last_followup", "age_at_index", "years_to_birth"])
print(clinical.head())
# Out:
# 2025-05-23 12:34:11,231 - bioneuralnet.utils.preprocess - INFO - [Inf]: Replaced 0 infinite values
# 2025-05-23 12:34:11,232 - bioneuralnet.utils.preprocess - INFO - [NaN]: Replaced 31384 NaNs after median imputation
# 2025-05-23 12:34:11,232 - bioneuralnet.utils.preprocess - INFO - [Zero-Var]: 39 columns dropped due to zero variance
# RNA shape: (769, 6000)
# METH shape: (769, 6000)
# miRNA shape: (769, 503)
# Clinical shape: (769, 118)
# Phenotype shape: (769, 1)
# Phenotype counts:
# pam50
# 3        419
# 4        140
# 1        130
# 2         46
# 0         34
# Name: count, dtype: int64
# Nan values in pam50 0
# 2025-05-23 12:34:11,612 - bioneuralnet.utils.preprocess - INFO - Selected top 15 features by RandomForest importance
#               age_at_diagnosis  days_to_birth  years_to_birth  age_at_index  \
# patient
# TCGA-3C-AAAU           20211.0       -20211.0            55.0          55.0
# TCGA-3C-AALI           18538.0       -18538.0            50.0          50.0
# TCGA-3C-AALJ           22848.0       -22848.0            62.0          62.0
# TCGA-3C-AALK           19074.0       -19074.0            52.0          52.0
# TCGA-4H-AAAK           18371.0       -18371.0            50.0          50.0
#
#               days_to_last_followup  year_of_diagnosis  number_of_lymph_nodes  \
# patient
# TCGA-3C-AAAU                 4047.0              -1.50                    1.5
# TCGA-3C-AALI                 4005.0              -1.75                    0.0
# TCGA-3C-AALJ                 1474.0               0.25                    0.0
# TCGA-3C-AALK                 1448.0               0.25                   -0.5
# TCGA-4H-AAAK                  348.0               0.75                    1.5
#
#               date_of_initial_pathologic_diagnosis  \
# patient
# TCGA-3C-AAAU                                 -1.50
# TCGA-3C-AALI                                 -1.75
# TCGA-3C-AALJ                                  0.25
# TCGA-3C-AALK                                  0.25
# TCGA-4H-AAAK                                  0.75
#
#               histological_type_infiltrating lobular carcinoma  \
# patient
# TCGA-3C-AAAU                                              True
# TCGA-3C-AALI                                             False
# TCGA-3C-AALJ                                             False
# TCGA-3C-AALK                                             False
# TCGA-4H-AAAK                                              True
#
#               histological_type_infiltrating ductal carcinoma  \
# patient
# TCGA-3C-AAAU                                            False
# TCGA-3C-AALI                                             True
# TCGA-3C-AALJ                                             True
# TCGA-3C-AALK                                             True
# TCGA-4H-AAAK                                            False
#
#               primary_diagnosis_Lobular carcinoma, NOS  morphology_8520/3  \
# patient
# TCGA-3C-AAAU                                      True               True
# TCGA-3C-AALI                                     False              False
# TCGA-3C-AALJ                                     False              False
# TCGA-3C-AALK                                     False              False
# TCGA-4H-AAAK                                      True               True
#
#               method_of_diagnosis_Core Biopsy  morphology_8500/3  \
# patient
# TCGA-3C-AAAU                            False              False
# TCGA-3C-AALI                             True               True
# TCGA-3C-AALJ                             True               True
# TCGA-3C-AALK                             True               True
# TCGA-4H-AAAK                             True              False
#
#               laterality_Right
# patient
# TCGA-3C-AAAU             False
# TCGA-3C-AALI              True
# TCGA-3C-AALJ              True
# TCGA-3C-AALK              True
# TCGA-4H-AAAK             False

# %% [markdown]
# ## Preparing Multi-Omics Data for downstream tasks
#
# 1. Check sample overlap.
#
# 2. Select top features.
#
#     - Although each omics dataset has already been filtered down to the top 6,000 features using the ANOVA F-test, this is still considered high-dimensional for most modeling tasks.
#
#     - To make the data more tractable and improve downstream performance, we apply ANOVA F-test again to select the top 1,000 most discriminative features from each dataset.
#
# 3. Combine datasets.
#
#     - Selected features from RNA, methylation, and miRNA are combined into a single dataset.
#
# 4. Clean missing values.
#
#     - Counts and removes any missing (nan) values from the combined dataset.
#
# 5. Build similarity graph.
#
#     - Creates a k-nearest neighbors graph from the transposed feature matrix.
#
#     - Other supported methods include correlation-based graphs, soft-thresholding (WGCNA-style), Gaussian kernels, and mutual information networks.
#
# Note: For more details on preprocessing functions and graph generation algorithms, see the [Utils documentation](https://bioneuralnet.readthedocs.io/en/latest/utils.html)

# %%
from sklearn.metrics import accuracy_score, f1_score
from bioneuralnet.utils.preprocess import top_anova_f_features
from bioneuralnet.utils.graph import gen_similarity_graph

meth_sel = top_anova_f_features(X_meth, brca_pam50, max_features=1000)
rna_sel = top_anova_f_features(X_rna, brca_pam50 ,max_features=1000)
mirna_sel = top_anova_f_features(X_mirna, brca_pam50,max_features=503)
X_train_full = pd.concat([meth_sel, rna_sel, mirna_sel], axis=1)

# we check again for nan values then drop if any
print(f"Nan values in X_train_full: {X_train_full.isna().sum().sum()}")
X_train_full = X_train_full.dropna()
print(f"Nan value in X_train_full after dropping: {X_train_full.isna().sum().sum()}")

print(f"X_train_full shape: {X_train_full.shape}")
# building the graph using the similarity graph function with k=15
A_train = gen_similarity_graph(X_train_full.T, k=15)

print(f"\nNetwork shape: {A_train.shape}")
# Out:
# 2025-05-23 12:34:12,482 - bioneuralnet.utils.preprocess - INFO - [Inf]: Replaced 0 infinite values
# 2025-05-23 12:34:12,482 - bioneuralnet.utils.preprocess - INFO - [NaN]: Replaced 0 NaNs after median imputation
# 2025-05-23 12:34:12,482 - bioneuralnet.utils.preprocess - INFO - [Zero-Var]: 0 columns dropped due to zero variance
# 2025-05-23 12:34:12,527 - bioneuralnet.utils.preprocess - INFO - Selected 1000 features by ANOVA (task=classification), 6000 significant, 0 padded
# 2025-05-23 12:34:13,385 - bioneuralnet.utils.preprocess - INFO - [Inf]: Replaced 0 infinite values
# 2025-05-23 12:34:13,385 - bioneuralnet.utils.preprocess - INFO - [NaN]: Replaced 0 NaNs after median imputation
# 2025-05-23 12:34:13,385 - bioneuralnet.utils.preprocess - INFO - [Zero-Var]: 0 columns dropped due to zero variance
# 2025-05-23 12:34:13,431 - bioneuralnet.utils.preprocess - INFO - Selected 1000 features by ANOVA (task=classification), 6000 significant, 0 padded
# 2025-05-23 12:34:13,506 - bioneuralnet.utils.preprocess - INFO - [Inf]: Replaced 0 infinite values
# 2025-05-23 12:34:13,507 - bioneuralnet.utils.preprocess - INFO - [NaN]: Replaced 0 NaNs after median imputation
# 2025-05-23 12:34:13,507 - bioneuralnet.utils.preprocess - INFO - [Zero-Var]: 0 columns dropped due to zero variance
# 2025-05-23 12:34:13,510 - bioneuralnet.utils.preprocess - INFO - Selected 503 features by ANOVA (task=classification), 465 significant, 38 padded
# Nan values in X_train_full: 0
# Nan value in X_train_full after dropping: 0
# X_train_full shape: (769, 2503)
#
# Network shape: (2503, 2503)

# %%
from bioneuralnet.downstream_task import DPMON

save = Path("/home/vicente/Github/BioNeuralNet/TCGA_BRCA/results")
brca_pam50 = brca_pam50.rename(columns={"pam50": "phenotype"})

dpmon = DPMON(
    adjacency_matrix=A_train,
    omics_list=[meth_sel, rna_sel, mirna_sel],
    phenotype_data=brca_pam50,
    clinical_data=clinical,
    repeat_num=3,
    tune=True,
    gpu=True, 
    cuda=0,
    output_dir=Path(save/"run"),
)

predictions_df, avg_accuracy = dpmon.run()
actual = predictions_df["Actual"]
pred = predictions_df["Predicted"]
dp_acc = accuracy_score(actual, pred)
dp_f1w = f1_score(actual, pred, average='weighted')
dp_f1m = f1_score(actual, pred, average='macro')

print(f"\nDPMON results:")
print(f"Accuracy: {dp_acc}")
print(f"F1 weighted: {dp_f1w}")
print(f"F1 macro: {dp_f1m}")
# Out:
# 2025-05-23 12:34:14,025 - bioneuralnet.downstream_task.dpmon - INFO - Output directory set to: /home/vicente/Github/BioNeuralNet/TCGA_BRCA/results/run
# 2025-05-23 12:34:14,025 - bioneuralnet.downstream_task.dpmon - INFO - Initialized DPMON with the provided parameters.
# 2025-05-23 12:34:14,026 - bioneuralnet.downstream_task.dpmon - INFO - Starting DPMON run.
# 2025-05-23 12:34:14,038 - bioneuralnet.downstream_task.dpmon - INFO - Running hyperparameter tuning for DPMON.
# 2025-05-23 12:34:14,039 - bioneuralnet.downstream_task.dpmon - INFO - Using GPU 0
# 2025-05-23 12:34:14,039 - bioneuralnet.downstream_task.dpmon - INFO - Slicing omics dataset based on network nodes.
# 2025-05-23 12:34:14,042 - bioneuralnet.downstream_task.dpmon - INFO - Building PyTorch Geometric Data object from adjacency matrix.
# 2025-05-23 12:34:14,109 - bioneuralnet.downstream_task.dpmon - INFO - Number of nodes in network: 2503
# 2025-05-23 12:34:14,109 - bioneuralnet.downstream_task.dpmon - INFO - Using clinical vars for node features: ['age_at_diagnosis', 'days_to_birth', 'years_to_birth', 'age_at_index', 'days_to_last_followup', 'year_of_diagnosis', 'number_of_lymph_nodes', 'date_of_initial_pathologic_diagnosis', 'histological_type_infiltrating lobular carcinoma', 'histological_type_infiltrating ductal carcinoma', 'primary_diagnosis_Lobular carcinoma, NOS', 'morphology_8520/3', 'method_of_diagnosis_Core Biopsy', 'morphology_8500/3', 'laterality_Right']
# 2025-05-23 12:34:17,366 - bioneuralnet.downstream_task.dpmon - INFO - Starting hyperparameter tuning for dataset shape: (769, 2504)
# 2025-05-23 12:34:18,207	INFO worker.py:1888 -- Started a local Ray instance.
# 2025-05-23 12:34:18,641	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2025-05-23 12:34:18,643	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# (raylet) Warning: The actor ImplicitFunc is very large (32 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (pid=395677) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
# (pid=395677)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# (pid=395677) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395677)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=395677) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395677)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# (pid=395677) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395677)   warnings.warn(
# (pid=395677) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395677)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (tune_train_n pid=395677) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_train_n pid=395677)   _log_deprecation_warning(
# (tune_train_n pid=395677) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00000/checkpoint_000000)
# (tune_train_n pid=395677) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00000/checkpoint_000001)
# (tune_train_n pid=395677) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00000/checkpoint_000002)
# (pid=395900) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=395900)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. " [repeated 2x across cluster]
# (pid=395900) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=395900)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. " [repeated 2x across cluster]
# (pid=395900) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=395900)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. " [repeated 2x across cluster]
# (pid=395900) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=395900)   warnings.warn( [repeated 2x across cluster]
# (pid=395900) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=395900)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. " [repeated 2x across cluster]
# (tune_train_n pid=395900) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_train_n pid=395900)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_train_n pid=395900) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00002/checkpoint_000003) [repeated 5x across cluster]
# (pid=395978) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
# (pid=395978)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# (pid=395978) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395978)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=395978) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395978)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# (pid=395978) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395978)   warnings.warn(
# (pid=395978) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=395978)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (pid=396057) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
# (pid=396057)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# (pid=396057) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396057)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=396057) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396057)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# (pid=396057) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396057)   warnings.warn(
# (pid=396057) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396057)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (tune_train_n pid=395978) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_train_n pid=395978)   _log_deprecation_warning(
# (tune_train_n pid=395978) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00003/checkpoint_000000) [repeated 97x across cluster]
# (tune_train_n pid=396057) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_train_n pid=396057)   _log_deprecation_warning(
# (pid=396135) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
# (pid=396135)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# (pid=396135) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396135)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=396135) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396135)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# (pid=396135) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396135)   warnings.warn(
# (pid=396135) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396135)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (tune_train_n pid=396057) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00004/checkpoint_000016) [repeated 17x across cluster]
# (tune_train_n pid=396135) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_train_n pid=396135)   _log_deprecation_warning(
# (tune_train_n pid=396135) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00005/checkpoint_000020) [repeated 21x across cluster]
# (tune_train_n pid=396135) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00005/checkpoint_000040) [repeated 20x across cluster]
# (tune_train_n pid=396135) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00005/checkpoint_000060) [repeated 20x across cluster]
# (tune_train_n pid=396135) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00005/checkpoint_000080) [repeated 20x across cluster]
# (pid=396222) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
# (pid=396222)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# (pid=396222) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396222)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=396222) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396222)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# (pid=396222) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396222)   warnings.warn(
# (pid=396222) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396222)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (tune_train_n pid=396135) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00005/checkpoint_000099) [repeated 19x across cluster]
# (tune_train_n pid=396222) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_train_n pid=396222)   _log_deprecation_warning(
# (pid=396379) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv [repeated 2x across cluster]
# (pid=396379)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. " [repeated 2x across cluster]
# (pid=396379) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=396379)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. " [repeated 2x across cluster]
# (pid=396379) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=396379)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. " [repeated 2x across cluster]
# (pid=396379) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=396379)   warnings.warn( [repeated 2x across cluster]
# (pid=396379) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb [repeated 2x across cluster]
# (pid=396379)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. " [repeated 2x across cluster]
# (tune_train_n pid=396300) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00007/checkpoint_000002) [repeated 4x across cluster]
# (tune_train_n pid=396379) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_train_n pid=396379)   _log_deprecation_warning( [repeated 2x across cluster]
# (tune_train_n pid=396379) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00008/checkpoint_000029) [repeated 30x across cluster]
# (tune_train_n pid=396379) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00008/checkpoint_000069) [repeated 40x across cluster]
# (pid=396459) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
# (pid=396459)   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# (pid=396459) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396459)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=396459) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396459)   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# (pid=396459) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396459)   warnings.warn(
# (pid=396459) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
# (pid=396459)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (tune_train_n pid=396379) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/vicente/ray_results/tune_dp/T89880_00008/checkpoint_000099) [repeated 30x across cluster]
# (tune_train_n pid=396459) /home/vicente/Github/BioNeuralNet/.enviroment/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_train_n pid=396459)   _log_deprecation_warning(
# 2025-05-23 12:35:30,014	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/vicente/ray_results/tune_dp' in 0.0044s.
# 2025-05-23 12:35:30,024 - bioneuralnet.downstream_task.dpmon - INFO - Best trial config: {'gnn_layer_num': 128, 'gnn_hidden_dim': 128, 'lr': 0.0009583495398019029, 'weight_decay': 0.0819865221991172, 'nn_hidden_dim1': 128, 'nn_hidden_dim2': 128, 'num_epochs': 512}
# 2025-05-23 12:35:30,024 - bioneuralnet.downstream_task.dpmon - INFO - Best trial final loss: 0.9468936920166016
# 2025-05-23 12:35:30,024 - bioneuralnet.downstream_task.dpmon - INFO - Best trial final accuracy: 0.9986996098829649
# 2025-05-23 12:35:30,027 - bioneuralnet.downstream_task.dpmon - INFO -    gnn_layer_num  gnn_hidden_dim        lr  weight_decay  nn_hidden_dim1  \
# 0            128             128  0.000958      0.081987             128
#
#    nn_hidden_dim2  num_epochs
# 0             128         512
# 2025-05-23 12:35:30,028 - bioneuralnet.downstream_task.dpmon - INFO - Best tuned parameters: {'gnn_layer_num': 128, 'gnn_hidden_dim': 128, 'lr': 0.0009583495398019029, 'weight_decay': 0.0819865221991172, 'nn_hidden_dim1': 128, 'nn_hidden_dim2': 128, 'num_epochs': 512}
# 2025-05-23 12:35:30,029 - bioneuralnet.downstream_task.dpmon - INFO - Best tuned parameters: {'gnn_layer_num': 128, 'gnn_hidden_dim': 128, 'lr': 0.0009583495398019029, 'weight_decay': 0.0819865221991172, 'nn_hidden_dim1': 128, 'nn_hidden_dim2': 128, 'num_epochs': 512}
# 2025-05-23 12:35:30,029 - bioneuralnet.downstream_task.dpmon - INFO - Running standard training with tuned parameters.
# 2025-05-23 12:35:30,029 - bioneuralnet.downstream_task.dpmon - INFO - Using GPU 0
# 2025-05-23 12:35:30,030 - bioneuralnet.downstream_task.dpmon - INFO - Slicing omics dataset based on network nodes.
# 2025-05-23 12:35:30,034 - bioneuralnet.downstream_task.dpmon - INFO - Building PyTorch Geometric Data object from adjacency matrix.
# 2025-05-23 12:35:30,106 - bioneuralnet.downstream_task.dpmon - INFO - Number of nodes in network: 2503
