# %% [markdown]
# # BioNeuralNet Cancer Example 1

# %%
from bioneuralnet.external_tools import get_cancer_data, preprocess_clinical, filter_common_patients
import cptac

ccrcc = cptac.Ccrcc()

genes_raw, proteins_raw, clinical_raw = get_cancer_data(ccrcc)
clinical_raw.to_csv("clinical_raw.csv")
genes, proteins, clinical_filtered = filter_common_patients(genes_raw, proteins_raw, clinical_raw)

clinical, phenotype = preprocess_clinical(clinical_filtered)

print(f"Genes shaope: {genes.shape}")
print(f"Proteins shape: {proteins.shape}")
print(f"Clinical shape: {clinical.shape}")
print(f"Phenotype shape: {phenotype.shape}")

print(genes.head())
print(proteins.head())
print(clinical.head())
print(phenotype.head())
# Out:
# /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/libpyg.so: undefined symbol: _ZN3c1010Dispatcher17runRecordFunctionERN2at14RecordFunctionESt17reference_wrapperIKNS_14FunctionSchemaEENS_11DispatchKeyE
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(
# /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/vicente/Github/BioNeuralNet/.venv/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# Common Patients: 103
# Genes shaope: (103, 60525)
# Proteins shape: (103, 11889)
# Clinical shape: (103, 11)
# Phenotype shape: (103, 1)
#             ENSG00000121410.12  ENSG00000268895.6  ENSG00000148584.15  \
# Patient_ID
# C3L-00004                0.041              0.041               0.004
# C3L-00010               -0.007             -0.007               0.007
# C3L-00011               -0.064             -0.064               0.007
# C3L-00026                0.010              0.010              -0.007
# C3L-00079                0.186              0.186               0.266
#
#             ENSG00000175899.15  ENSG00000245105.4  ENSG00000166535.20  \
# Patient_ID
# C3L-00004                0.015              0.015               0.015
# C3L-00010               -0.001             -0.001              -0.001
# C3L-00011                0.004              0.004               0.004
# C3L-00026                0.008              0.008               0.008
# C3L-00079               -0.023             -0.023              -0.023
#
#             ENSG00000256661.1  ENSG00000256904.1  ENSG00000256069.7  \
# Patient_ID
# C3L-00004               0.015              0.015              0.015
# C3L-00010              -0.001             -0.001             -0.001
# C3L-00011               0.004              0.004              0.004
# C3L-00026               0.008              0.008              0.008
# C3L-00079              -0.023             -0.023             -0.023
#
#             ENSG00000184389.9  ...  ENSG00000198455.4  ENSG00000070476.15  \
# Patient_ID                     ...
# C3L-00004              -0.004  ...             -0.016               0.001
# C3L-00010              -0.005  ...             -0.037               0.005
# C3L-00011              -0.037  ...             -0.690               0.007
# C3L-00026               0.000  ...             -0.624              -0.007
# C3L-00079               0.134  ...              0.167               0.314
#
#             ENSG00000203995.10  ENSG00000232242.2  ENSG00000162378.13  \
# Patient_ID
# C3L-00004               -0.004             -0.009              -0.004
# C3L-00010               -0.005              0.001              -0.005
# C3L-00011                0.018             -0.676               0.018
# C3L-00026                0.000              0.003               0.000
# C3L-00079                0.134             -0.077               0.134
#
#             ENSG00000159840.16  ENSG00000274572.1  ENSG00000074755.15  \
# Patient_ID
# C3L-00004                0.024             -0.009               0.021
# C3L-00010                0.003              0.006               0.007
# C3L-00011                0.007              0.007              -0.697
# C3L-00026                0.669             -0.008               0.001
# C3L-00079                0.134              0.462               0.003
#
#             ENSG00000272920.1  ENSG00000266919.3
# Patient_ID
# C3L-00004               0.021              0.021
# C3L-00010               0.007              0.007
# C3L-00011              -0.697             -0.015
# C3L-00026               0.001              0.001
# C3L-00079               0.003              0.001
#
# [5 rows x 60525 columns]
#             ENSP00000000233.5  ENSP00000000412.3  ENSP00000000442.6  \
# Patient_ID
# C3L-00004            0.248796           0.308289          -0.315825
# C3L-00010            0.245087           0.131992          -0.016811
# C3L-00011            0.576821           0.443678          -0.544452
# C3L-00026            0.293042           0.250350           0.142924
# C3L-00079            0.174315           0.026805          -0.663191
#
#             ENSP00000001008.4  ENSP00000002125.4  ENSP00000002165.5  \
# Patient_ID
# C3L-00004            0.051528          -0.323475          -0.720420
# C3L-00010           -0.114728          -0.816992           0.104260
# C3L-00011            0.120776          -0.075035          -0.738826
# C3L-00026           -0.173812           0.589458           0.238597
# C3L-00079            0.075943          -0.240099          -0.293380
#
#             ENSP00000002501.6  ENSP00000003084.6  ENSP00000003100.8  \
# Patient_ID
# C3L-00004                 NaN          -0.832085          -0.629139
# C3L-00010                 NaN           1.266034          -0.573329
# C3L-00011                 NaN          -0.484732          -0.725274
# C3L-00026            0.957386          -3.178976           0.372489
# C3L-00079                 NaN           0.008966          -0.469829
#
#             ENSP00000003302.4  ...  ENSP00000500245.1  ENSP00000500275.1  \
# Patient_ID                     ...
# C3L-00004           -0.317251  ...           0.359093           1.609902
# C3L-00010           -0.172712  ...          -1.592004          -0.542294
# C3L-00011            1.079570  ...          -0.523301          -0.389680
# C3L-00026            0.404721  ...          -0.249875          -1.492455
# C3L-00079                 NaN  ...          -1.423105          -0.921139
#
#             ENSP00000500313.1  ENSP00000500633.1  ENSP00000500710.1  \
# Patient_ID
# C3L-00004            0.054346          -0.471825          -0.095824
# C3L-00010                 NaN          -0.208478          -0.143536
# C3L-00011                 NaN           0.550085          -1.617542
# C3L-00026                 NaN           0.005406          -0.281776
# C3L-00079                 NaN          -0.042932          -0.921862
#
#             ENSP00000501064.1  ENSP00000501126.1  ENSP00000501261.1  \
# Patient_ID
# C3L-00004            0.240579           0.689392                NaN
# C3L-00010            0.049889           0.499405           1.422138
# C3L-00011            0.485815          -0.327129                NaN
# C3L-00026            0.057764          -0.073197                NaN
# C3L-00079            0.385364                NaN                NaN
#
#             ENSP00000501300.1  ENSP00000501491.1
# Patient_ID
# C3L-00004           -0.072279          -0.655139
# C3L-00010           -0.058976          -0.189293
# C3L-00011            0.344999          -0.688779
# C3L-00026           -0.159555          -0.023920
# C3L-00079            0.387207          -1.057636
#
# [5 rows x 11889 columns]
#              age  sex  tumor_site  tumor_laterality  tumor_focality  \
# Patient_ID
# C3L-00004   72.0    1           0                 0               1
# C3L-00010   30.0    1           0                 0               1
# C3L-00011   63.0    0           0                 1               1
# C3L-00026   65.0    0           0                 1               1
# C3L-00079   49.0    1           0                 1               1
#
#             tumor_size_cm  histologic_grade    bmi  alcohol_consumption  \
# Patient_ID
# C3L-00004            12.0                 2  22.80                    4
# C3L-00010             6.5                 2  34.15                    1
# C3L-00011            12.0                 3  27.47                    0
# C3L-00026             2.0                 2  28.23                    4
# C3L-00079            14.0                 2  37.88                    4
#
#             tobacco_smoking_history  medical_condition
# Patient_ID
# C3L-00004                         0                 68
# C3L-00010                         2                 13
# C3L-00011                         3                 60
# C3L-00026                         3                 26
# C3L-00079                         3                 16
#             tumor_stage_pathological
# Patient_ID
# C3L-00004                          1
# C3L-00010                          0
# C3L-00011                          1
# C3L-00026                          0
# C3L-00079                          1

# %%
from sklearn.feature_selection import VarianceThreshold
import pandas as pd

print("Before filtering:\n")
print(f"Gnes has {genes.isnull().sum().sum()} missing values")
print(f"Proteins has {proteins.isnull().sum().sum()} missing values")

# remove columns with Nan values
genes = genes.dropna(axis=1, how='any')
proteins = proteins.dropna(axis=1, how='any')

print("\nAfter Droping Nans:")
print(genes.shape)
print(proteins.shape)

variance_filter = VarianceThreshold(threshold=0.2)
genomics_array = variance_filter.fit_transform(genes)

genomics = pd.DataFrame(
    genomics_array,
    index=genes.index,
    columns=genes.columns[variance_filter.get_support()]
)

variance_filter_prot = VarianceThreshold(threshold=0.2)
proteomics_array = variance_filter_prot.fit_transform(proteins)

proteomics = pd.DataFrame(
    proteomics_array,
    index=proteins.index,
    columns=proteins.columns[variance_filter_prot.get_support()]
)

print("After filtering:")
print("Genomics shape:", genomics.shape)
print("Proteomics shape:", proteomics.shape)
print(genomics.head())
print(proteomics.head())
# Out:
# Before filtering:
#
# Gnes has 0 missing values
# Proteins has 261664 missing values
#
# After Droping Nans:
# (103, 60525)
# (103, 7016)
# After filtering:
# Genomics shape: (103, 539)
# Proteomics shape: (103, 1746)
#             ENSG00000286130.1  ENSG00000278847.1  ENSG00000275310.1  \
# Patient_ID
# C3L-00004              -0.911             -0.911             -0.911
# C3L-00010              -1.019             -1.019             -1.019
# C3L-00011              -0.145             -0.145             -0.145
# C3L-00026               0.023              0.023              0.023
# C3L-00079              -1.137             -1.137             -1.137
#
#             ENSG00000286120.1  ENSG00000286173.1  ENSG00000233619.1  \
# Patient_ID
# C3L-00004              -0.911             -0.911             -0.911
# C3L-00010              -1.019             -1.019             -1.019
# C3L-00011              -0.145             -0.145             -0.147
# C3L-00026               0.023              0.023              0.023
# C3L-00079              -1.137             -1.137             -1.137
#
#             ENSG00000284380.1  ENSG00000235094.3  ENSG00000275352.1  \
# Patient_ID
# C3L-00004              -0.911             -0.911             -0.911
# C3L-00010              -1.019             -1.019             -1.019
# C3L-00011              -0.147             -0.145             -0.145
# C3L-00026               0.023              0.023              0.023
# C3L-00079              -1.137             -1.137             -1.137
#
#             ENSG00000278197.1  ...  ENSG00000236379.2  ENSG00000230819.1  \
# Patient_ID                     ...
# C3L-00004              -0.911  ...             -0.911             -0.911
# C3L-00010              -1.019  ...             -1.019             -1.019
# C3L-00011              -0.147  ...             -0.147             -0.147
# C3L-00026               0.023  ...              0.023              0.023
# C3L-00079              -1.137  ...             -1.137             -1.137
#
#             ENSG00000224634.1  ENSG00000241200.1  ENSG00000244246.1  \
# Patient_ID
# C3L-00004              -0.911             -0.911             -0.911
# C3L-00010              -1.019             -1.019             -1.019
# C3L-00011              -0.145             -0.145             -0.145
# C3L-00026               0.023              0.023              0.023
# C3L-00079              -1.137             -1.137             -1.137
#
#             ENSG00000239893.2  ENSG00000217896.2  ENSG00000228764.1  \
# Patient_ID
# C3L-00004              -0.911             -0.911             -0.911
# C3L-00010              -1.019             -1.019             -1.019
# C3L-00011              -0.145             -0.147             -0.147
# C3L-00026               0.023              0.023              0.023
# C3L-00079              -1.137             -1.137             -1.137
#
#             ENSG00000232522.1  ENSG00000215603.4
# Patient_ID
# C3L-00004              -0.911             -0.911
# C3L-00010              -1.019             -1.019
# C3L-00011              -0.147             -0.145
# C3L-00026               0.023              0.023
# C3L-00079              -1.137             -1.137
#
# [5 rows x 539 columns]
#             ENSP00000003100.8  ENSP00000004982.3  ENSP00000005178.5  \
# Patient_ID
# C3L-00004           -0.629139          -0.963552           1.071050
# C3L-00010           -0.573329          -2.629349          -0.601561
# C3L-00011           -0.725274          -2.258016          -0.666070
# C3L-00026            0.372489          -1.087033           1.488454
# C3L-00079           -0.469829          -0.882213           1.057320
#
#             ENSP00000005260.8  ENSP00000005587.2  ENSP00000006777.6  \
# Patient_ID
# C3L-00004           -0.709452           0.935768          -0.605336
# C3L-00010           -0.303856           0.229396          -0.792211
# C3L-00011            1.859668          -0.529298          -0.128768
# C3L-00026           -0.509028           0.074067           0.517890
# C3L-00079            0.901664           0.776101          -0.157385
#
#             ENSP00000009180.4  ENSP00000009530.7  ENSP00000010404.2  \
# Patient_ID
# C3L-00004           -0.656928           0.289200          -0.964154
# C3L-00010           -0.530668          -0.073076          -0.486055
# C3L-00011           -1.710060           0.193294           0.594775
# C3L-00026           -0.414820           0.194276          -0.018702
# C3L-00079           -0.562946           0.811032          -1.001052
#
#             ENSP00000011653.4  ...  ENSP00000498075.1  ENSP00000498408.1  \
# Patient_ID                     ...
# C3L-00004            0.563387  ...           0.433326          -0.797754
# C3L-00010            0.414442  ...           0.580986          -0.119409
# C3L-00011            0.110896  ...           1.647099           1.856893
# C3L-00026           -0.310567  ...           0.459815           0.166078
# C3L-00079            0.610429  ...          -0.395737          -0.535006
#
#             ENSP00000498441.1  ENSP00000498786.1  ENSP00000498932.1  \
# Patient_ID
# C3L-00004           -0.506954          -0.363214          -0.215305
# C3L-00010            0.485804          -0.052700          -0.386301
# C3L-00011            1.350262           0.026752          -0.558920
# C3L-00026           -0.822164           0.712062          -0.543199
# C3L-00079            0.248644          -0.265680           0.033349
#
#             ENSP00000499129.1  ENSP00000499271.1  ENSP00000499832.1  \
# Patient_ID
# C3L-00004           -0.408601          -1.092168          -0.045349
# C3L-00010           -0.272673          -0.564413          -1.100544
# C3L-00011            1.512444          -2.248855          -1.077198
# C3L-00026            0.163810          -0.603413          -0.455064
# C3L-00079            0.039393          -1.616319          -1.987001
#
#             ENSP00000500245.1  ENSP00000501491.1
# Patient_ID
# C3L-00004            0.359093          -0.655139
# C3L-00010           -1.592004          -0.189293
# C3L-00011           -0.523301          -0.688779
# C3L-00026           -0.249875          -0.023920
# C3L-00079           -1.423105          -1.057636
#
# [5 rows x 1746 columns]

# %%
from bioneuralnet.external_tools import SmCCNet

smccnet = SmCCNet(
    phenotype_df=phenotype,
    omics_dfs=[genomics,proteomics],
    data_types=["genomics","proteomics"],
    output_dir="cancer_output_2",
)
global_network, smccnet_clusters = smccnet.run()
# Out:
# 2025-04-04 20:32:32,646 - bioneuralnet.external_tools.smccnet - INFO - Initialized SmCCNet with parameters:
# 2025-04-04 20:32:32,646 - bioneuralnet.external_tools.smccnet - INFO - K-Fold: 5
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - Summarization: NetSHy
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - Evaluation method:
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - ncomp_pls: 0
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - subSampNum: 1000
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - BetweenShrinkage: 5.0
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - Seed: 723
# 2025-04-04 20:32:32,647 - bioneuralnet.external_tools.smccnet - INFO - Output directory set to: cancer_output_2
# 2025-04-04 20:32:32,648 - bioneuralnet.external_tools.smccnet - INFO - Starting SmCCNet workflow.
# 2025-04-04 20:32:32,648 - bioneuralnet.external_tools.smccnet - INFO - Validating and serializing input data for SmCCNet...
# 2025-04-04 20:32:32,648 - bioneuralnet.external_tools.smccnet - INFO - All DataFrames already share the same named index. No rename needed.
# 2025-04-04 20:32:32,668 - bioneuralnet.external_tools.smccnet - INFO - Serialized omics_1 with 103 samples.
# 2025-04-04 20:32:32,760 - bioneuralnet.external_tools.smccnet - INFO - Serialized omics_2 with 103 samples.
# 2025-04-04 20:32:32,760 - bioneuralnet.external_tools.smccnet - INFO - Executing SmCCNet R script...
# 2025-04-04 20:34:58,036 - bioneuralnet.external_tools.smccnet - INFO - SMCCNET R script output:
# Allowing multi-threading with up to 32 threads.
#
# **********************************
# * Welcome to Automated SmCCNet! *
# **********************************
#
# This project uses multiomics CCA
#
# --------------------------------------------------
# >> Now determining the scaling factor for multi-omics analysis...
# --------------------------------------------------
#
#
# The scaling factor selection is:
#
# genomics-proteomics: 0.129377330523842
# genomics-Phenotype: 1
# proteomics-Phenotype: 1
#
# --------------------------------------------------
# >> Determining the best penalty selection through cross-validation...
# --------------------------------------------------
#
#
# The best penalty term for genomics after 5-fold cross-validation is: 0.5
# The best penalty term for proteomics after 5-fold cross-validation is: 0.5
# with testing canonical correlation = 0.751, and prediction error = 0.549
# Now running multi-omics CCA with best penalty term on the complete dataset.
#
# --------------------------------------------------
# >> Now starting network clustering...
# --------------------------------------------------
#
# Clustering completed...
#
# --------------------------------------------------
# >> Now starting network pruning and summarization score extraction...
# --------------------------------------------------
#
# There are 3 network modules before pruning
#  Now extracting subnetwork for network module  1
# Network module 1 Result:The final network size is: 70 with maximum PC correlation w.r.t. phenotype to be: 0.36
#  Now extracting subnetwork for network module  2
# Network module 2 Result:The final network size is: 46 with maximum PC correlation w.r.t. phenotype to be: -0.224
#  Now extracting subnetwork for network module  3
# Network module 3 Result:The final network size is: 21 with maximum PC correlation w.r.t. phenotype to be: 0.075
#
# ************************************
# *   Execution Finished!            *
# *   Automated SmCCNet Completed!   *
# ************************************
#
# There are 4 files stored in the local directory:
# 1. CVResult.csv: cross-validation result.
# 2. CVFold.Rdata: omics and phenotype data splited into different folds.
# 3. globalNetwork.Rdata: global network adjacency matrix, omics data, phenotype.
# 4. size_a_net_b.Rdata: subnetworks result file after clustering and network pruning.
# SUBNETWORK RESULT FILE CONTAINS:
# 1. correlation_sub: correlation matrix for the subnetwork.
# 2. M: adjacency matrix for the subnetwork.
# 3. omics_corelation_data: individual molecular feature correlation with phenotype.
# 4. pc_correlation: first 3 PCs correlation with phenotype.
# 5. pc_loading: principal component loadings.
# 6. pca_x1_score: principal component score and phenotype data.
# 7. mod_size: number of molecular features in the subnetwork.
# 8. sub_type: type of feature for each molecular features.
#
# NOTE:
# 1. The results are saved in the user-specified directory.
#    If not specified, use 'getwd()' to find the current working directory.
#
# 2. The results are in 'size_a_net_b.Rdata', where:
#    'a' = network size, 'b' = module number.
#
# 3. To prevent overwriting result files across projects, rename the result file after each run.
#
# 4. Subnetwork visualization can be done through shinyApp or cytoscape. Please refer to the network visualization section in the multi-omics or single-omics vignette for more detail. For the Shiny app, visit: https://smccnet.shinyapps.io/smccnetnetwork/
#
# ************************************
#
# 2025-04-04 20:34:58,037 - bioneuralnet.external_tools.smccnet - WARNING - SMCCNET R script warnings/errors:
# Loading required package: dynamicTreeCut
# Loading required package: fastcluster
#
# Attaching package: ‘fastcluster’
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
# Attaching package: ‘WGCNA’
#
# The following object is masked from ‘package:stats’:
#
#     cor
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# DEBUG: We have 103 samples in Y. Range: [0, 1]
# DEBUG: Omics data shapes:
#   Omics 1: 103 x 539
#   Omics 2: 103 x 1746
# Warning message:
# In split.default(seq_len(nrow(omics_list[[1]])), sample(seq_len(nrow(omics_list[[1]])),  :
#   data length is not a multiple of split variable
# Debug fold #1 => size: 21
# Debug fold #2 => size: 20
# Debug fold #3 => size: 21
# Debug fold #4 => size: 20
# Debug fold #5 => size: 21
# Multi-omics CCA scenario
#
#  Progress: ───────────────────────────────────────────────────              100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%
#  Progress: ──────────────────────────────────────────────────────────────── 100%Warning message:
# In split.default(1:nrow(X[[1]]), sample(1:nrow(X[[1]]), Kfold)) :
#   data length is not a multiple of split variable
# Current working directory: /home/vicente/Github/BioNeuralNet/cancer_output_2
# Found files: /home/vicente/Github/BioNeuralNet/cancer_output_2/size_21_net_3.Rdata, /home/vicente/Github/BioNeuralNet/cancer_output_2/size_46_net_2.Rdata, /home/vicente/Github/BioNeuralNet/cancer_output_2/size_70_net_1.Rdata
# Processing file: /home/vicente/Github/BioNeuralNet/cancer_output_2/size_21_net_3.Rdata
#
# Subnetwork matrix from /home/vicente/Github/BioNeuralNet/cancer_output_2/size_21_net_3.Rdata written to size_21_net_3.csv
#
#
# Processing file: /home/vicente/Github/BioNeuralNet/cancer_output_2/size_46_net_2.Rdata
#
# Subnetwork matrix from /home/vicente/Github/BioNeuralNet/cancer_output_2/size_46_net_2.Rdata written to size_46_net_2.csv
#
#
# Processing file: /home/vicente/Github/BioNeuralNet/cancer_output_2/size_70_net_1.Rdata
#
# Subnetwork matrix from /home/vicente/Github/BioNeuralNet/cancer_output_2/size_70_net_1.Rdata written to size_70_net_1.csv
#
#
#
# 2025-04-04 20:34:58,037 - bioneuralnet.external_tools.smccnet - INFO - Reading Global Network from: cancer_output_2/GlobalNetwork.csv
# 2025-04-04 20:34:58,253 - bioneuralnet.external_tools.smccnet - INFO - Global Network shape: (2285, 2285)
# 2025-04-04 20:34:58,257 - bioneuralnet.external_tools.smccnet - INFO - Found 3 clusters in cancer_output_2.
# 2025-04-04 20:34:58,257 - bioneuralnet.external_tools.smccnet - INFO - GlobalNetwork stored at index 0 and clusters stored as a list of dataframes at index 1.
# 2025-04-04 20:34:58,257 - bioneuralnet.external_tools.smccnet - INFO - SmCCNet workflow completed successfully.

# %%
import numpy as np


matrix = global_network.values
num_nonzero = np.count_nonzero(matrix)
total_entries = matrix.size
density = num_nonzero / total_entries
sparsity = 1 - density

print(f"Number of nonzero entries: {num_nonzero}")
print(f"Total entries: {total_entries}")
print(f"Density (nonzero fraction): {density:.4f}")
print(f"Sparsity (zero fraction): {sparsity:.4f}")


matrix = smccnet_clusters[0].values
num_nonzero = np.count_nonzero(matrix)
total_entries = matrix.size
density = num_nonzero / total_entries
sparsity = 1 - density

print(f"Number of nonzero entries: {num_nonzero}")
print(f"Total entries: {total_entries}")
print(f"Density (nonzero fraction): {density:.4f}")
print(f"Sparsity (zero fraction): {sparsity:.4f}")


matrix = smccnet_clusters[1].values
num_nonzero = np.count_nonzero(matrix)
total_entries = matrix.size
density = num_nonzero / total_entries
sparsity = 1 - density

print(f"Number of nonzero entries: {num_nonzero}")
print(f"Total entries: {total_entries}")
print(f"Density (nonzero fraction): {density:.4f}")
print(f"Sparsity (zero fraction): {sparsity:.4f}")


matrix = smccnet_clusters[2].values
num_nonzero = np.count_nonzero(matrix)
total_entries = matrix.size
density = num_nonzero / total_entries
sparsity = 1 - density

print(f"Number of nonzero entries: {num_nonzero}")
print(f"Total entries: {total_entries}")
print(f"Density (nonzero fraction): {density:.4f}")
print(f"Sparsity (zero fraction): {sparsity:.4f}")
# Out:
# Number of nonzero entries: 1079462
# Total entries: 5221225
# Density (nonzero fraction): 0.2067
# Sparsity (zero fraction): 0.7933
# Number of nonzero entries: 2070
# Total entries: 2116
# Density (nonzero fraction): 0.9783
# Sparsity (zero fraction): 0.0217
# Number of nonzero entries: 4830
# Total entries: 4900
# Density (nonzero fraction): 0.9857
# Sparsity (zero fraction): 0.0143
# Number of nonzero entries: 420
# Total entries: 441
# Density (nonzero fraction): 0.9524
# Sparsity (zero fraction): 0.0476

# %%
import bioneuralnet
print("BioNeuralNet version:", bioneuralnet.__version__)
# Out:
# BioNeuralNet version: 1.0
